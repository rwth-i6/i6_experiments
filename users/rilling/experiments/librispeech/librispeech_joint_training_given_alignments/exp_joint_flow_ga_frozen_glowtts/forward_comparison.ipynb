# %%
import sys
sys.path.append("/u/lukas.rilling/dev/")
import pandas as pd
import numpy as np
import glob
import os
from IPython.display import Audio
from IPython.core.display import display

import mimetypes
mimetypes.add_type("audio/ogg", ".ogg")

# %load_ext autoreload
# %autoreload 2
# Out:
# /tmp/ipykernel_2748792/2049839218.py:8: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
globs = [
    "/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/TTS_models/glowTTS/enc768/200ep/dec_drop_0.05/tts_eval_gl/forward/output/audio_files/",
    "/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector*/*/ce*/tts_eval_gl/forward/output/audio_files/",
    # "/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.01/tts_eval_gl/forward/output",
    "/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector*/200ep/*/ce*/tts_eval_gl/forward/output/audio_files/",
]
lr_files = []
for g in globs:
    lr_files += glob.glob(g)

common_prefix = os.path.commonpath(lr_files)
common_sufix = os.path.commonpath([l[::-1] for l in lr_files])[::-1]

names = []
for f in lr_files:
    names.append(f.removeprefix(common_prefix).removesuffix(common_sufix))

files = dict(zip(lr_files, names))

sequence_names = os.listdir(list(files.keys())[0])

files
# Out:
# {'/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/TTS_models/glowTTS/enc768/200ep/dec_drop_0.05/tts_eval_gl/forward/output/audio_files/': '/TTS_models/glowTTS/enc768/200ep/dec_drop_0.05/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.01/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.01/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.01/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.01/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/basic_init/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/tts_pretrained/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_1.0/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_1.0/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_1.0/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_1.0/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/tts_pretrained/ce_ls_0.1/',
#  '/u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/': '/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/basic_init/ce_ls_0.1/'}

# %%
sequence_index = 55
sequence_name = sequence_names[sequence_index]

for folder, name in files.items():
    path = folder + sequence_name
    print(path)
    if os.path.exists(path):
        with open(folder.replace("forward/output/audio_files/", "nisqa_mos/average").replace("alias", "output")) as f:
            nisqa_result = f.readline()
        print(name)
        print("AutoMOS: " + nisqa_result)
        display(Audio(path))
# Out:
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/TTS_models/glowTTS/enc768/200ep/dec_drop_0.05/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /TTS_models/glowTTS/enc768/200ep/dec_drop_0.05/
# AutoMOS: 3.4771760467039163
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.01/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.01/
# AutoMOS: 1.9955415346351753
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/basic_init/ce_ls_0.1/
# AutoMOS: 1.3495199719510704
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.1/
# AutoMOS: 1.7334384575070614
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.01/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector_v2/tts_pretrained/ce_ls_0.01/
# AutoMOS: 1.6213673570479055
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/basic_init/ce_ls_0.1/
# AutoMOS: 2.3951956369724883
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_cnn_x_vector/tts_pretrained/ce_ls_0.1/
# AutoMOS: 2.342592060091011
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_0.1/
# AutoMOS: 2.058361479485652
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_1.0/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/basic_init/ce_ls_1.0/
# AutoMOS: 2.0631651215819247
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_0.1/
# AutoMOS: 2.059862890685222
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_1.0/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector_v2/200ep/tts_pretrained/ce_ls_1.0/
# AutoMOS: 2.0530003230885208
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/tts_pretrained/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/tts_pretrained/ce_ls_0.1/
# AutoMOS: 2.7276094821819745
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# /u/lukas.rilling/experiments/glow_tts_asr_v2/alias/experiments/librispeech/joint_training/given_alignments/raw_audio/joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/basic_init/ce_ls_0.1/tts_eval_gl/forward/output/audio_files/train-clean-100_118-124588-0013_118-124588-0013.ogg
# /joint_models/flow_given_alignment/ga_glowTTS_ASR_ffn_x_vector/200ep/basic_init/ce_ls_0.1/
# AutoMOS: 1.9181333533914915
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
